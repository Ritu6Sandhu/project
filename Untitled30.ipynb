# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('Business Analyst -ABC University (1).csv')
df.head()
# Out:
#               Name      Mobile Lead Origin Country        State     City  \
# 0        Ram Yadav  9830******         API   India  West Bengal  Kolkata
# 1  Anamika Bairagi  7439******         API   India  West Bengal  Barasat
# 2       Puja Singh  7003******         API   India  West Bengal  Kolkata
# 3     Jhuma Haldar  9831******         API   India  West Bengal  Kolkata
# 4      Rajan Kumar  9128******         API   India  West Bengal  Kolkata
#
#   Instance Instance Date     Campaign    Lead Stage  ...  \
# 0  Primary    09-10-2023  Meta/85/API     Untouched  ...
# 1  Primary    09-10-2023  Meta/84/API  Disqualified  ...
# 2  Primary    09-10-2023  Meta/85/API   No Response  ...
# 3  Primary    09-10-2023  Meta/88/API  Disqualified  ...
# 4  Primary    09-10-2023  Meta/85/API  Disqualified  ...
#
#   Mobile Verification Status Registration Device  \
# 0                         No                 NaN
# 1                         No                 NaN
# ...

# %%
#Distribution of Lead Stage
lead_stage_distribution = df['Lead Stage'].value_counts()

# %%
#Distribution of Enrollment Status
enrollment_status_distribution = df['Enrolment Status'].value_counts()

# %%
 #Distribution of Course preferences
course_distribution = df['Course'].value_counts()

# Distribution of Campaigns
campaign_distribution = df['Campaign'].value_counts()

# Results
lead_stage_distribution, enrollment_status_distribution, course_distribution.head(10), campaign_distribution.head(10)
# Out:
# (Disqualified          17446
#  NR Closed              5936
#  No Response            4139
#  Qualified              2884
#  Asked for Callback     1029
#  Untouched                99
#  PhD Enquiry              56
#  Sports Quota             15
#  Name: Lead Stage, dtype: int64,
#  No     31469
#  Yes      135
#  Name: Enrolment Status, dtype: int64,
#  B.Com (H)                                                                                                                2697
#  B.Ed                                                                                                                     2355
#  BA LLB (Hons.)                                                                                                           1316
#  B.Pharm                                                                                                                   988
# ...
